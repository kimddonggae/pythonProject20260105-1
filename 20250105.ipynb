# %% [markdown]
# ### 2026-01-05

# %% [markdown]
# #### 시작하기

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
Hello = "Hellp Python"

# %%
print(Hello)
# Out:
# Hellp Python

# %%
type(int("10"))
# Out:
# int

# %%
데이터 타입 -> type()
형 변환

# %%
mynum=10
print(mynum)
# Out:
# 10

# %%
10+10
# Out:
# 20

# %%
7/2
# Out:
# 3.5

# %%
10//2 -> 몫
# Out:
# 5

# %%
10%2 -> 나머지
# Out:
# 0

# %%
2**4
# Out:
# 16

# %%
num1=7
num2=3

# %%
num1=15
num2=7
sum=num1+num2
print(sum, num1-num2, num1*num2, num1/num2, num1//num2, num1%num2, num1**num2)
# Out:
# 22 8 105 2.142857142857143 2 1 170859375

# %%
num1=15
num2=7
sum=num1+num2
print(sum, num1-num2, num1*num2, num1/num2, num1//num2, num1%num2, num1**num2)
# Out:
# 22 8 105 2.142857142857143 2 1 170859375

# %%
#미션2
a=1234
#천의 자리 숫자만 추출 -> 1
#백의 자리 숫자만 추출 -> 2
#십의 자리 숫자만 추출 -> 3
#일의 자리 숫자만 추출 -> 4

# %%
a=1234
print(a//1000)
print((a-1000)//100)
print((a-1200)//10)
print((a-1230))
# Out:
# 1
# 2
# 3
# 4

# %%
a=1234
print(a//1000)
b=a//100
print(b%10)
c=a//10
print(c%10)
print(a%10)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ### 비교연산자

# %%
5!=2
# Out:
# True

# %% [markdown]
# ## 사용자 입력

# %%
input()
# Out:
# 'Hello Python'

# %%
#미션
사용자로부터 2개 숫자 입력 받아서 덧셈, 뺄셈, 곱셈, 나눗셈 결과 출력해주세요.

# %%
a=int(input("숫자를 입력하시오:"))
b=int(input("숫자를 입력하시오:"))
print("덧셈:", a, "+", b, "=", a+b)
print("뺄셈:", a, "-", b, "=",a-b)
print("곱셈:", a, "*", b, "=",a*b)
print("나눗셈:", a, "/", b, "=",a/b)
# Out:
# 덧셈: 10 + 2 = 12
# 뺄셈: 10 - 2 = 8
# 곱셈: 10 * 2 = 20
# 나눗셈: 10 / 2 = 5.0

# %% [markdown]
# ### 조건문

# %%
if 조건: 
    수행할 명령1
    수행할 명령2

# %%
a=int(input("금액:"))

if a>=3000 :
    print("택시를 탄다")
    print("밥도 먹는다")

else : 
    print("참는다")
print("if문 종료")
# Out:
# 택시를 탄다
# 밥도 먹는다
# if문 종료

# %%
#짝수가 입력되었을 때만 짝수라고 출력해 주세요

# %%
a=int(input("숫자:"))

if a%2==0 : 
    print("짝수")
else :
    print("홀수입니다.")
print("종료.")
# Out:
# 홀수입니다.
# 종료.

# %%
a=int(input("성적 입력:"))

if a>=90 : 
    print("A")
elif 90>a>=80 :
    print("B")
elif 80>a>=70 :
    print("C")
elif 70>a>=60 :
    print("D")
else :
    print("F")
# Out:
# A

# %%
for i in range (1,6*2,2):
    print(f"{i}만큼 Hi")
# Out:
# 1만큼 Hi
# 3만큼 Hi
# 5만큼 Hi
# 7만큼 Hi
# 9만큼 Hi
# 11만큼 Hi

# %%
sum=1
for x in range(1,11):
    sum=sum*x
print(sum)
# Out:
# 3628800

# %%
for i in range(1,10):
    print(f"{i}x2={i*2}")
# Out:
# 1x2=2
# 2x2=4
# 3x2=6
# 4x2=8
# 5x2=10
# 6x2=12
# 7x2=14
# 8x2=16
# 9x2=18

# %%
d=int(input("구구단 몇 단을 실행할까요?"))
for i in range (1,10):
    print(f"{d}x{i}={d*i}")
# Out:
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45

# %%
for i in range (2,10):
    for j in range(1,10):
        print(f'{i}x{j}={i*j}')
# Out:
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
# 3x1=3
# 3x2=6
# 3x3=9
# 3x4=12
# 3x5=15
# 3x6=18
# 3x7=21
# 3x8=24
# 3x9=27
# 4x1=4
# 4x2=8
# 4x3=12
# 4x4=16
# 4x5=20
# 4x6=24
# 4x7=28
# 4x8=32
# 4x9=36
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
# 6x1=6
# 6x2=12
# 6x3=18
# 6x4=24
# 6x5=30
# 6x6=36
# 6x7=42
# 6x8=48
# 6x9=54
# 7x1=7
# 7x2=14
# 7x3=21
# 7x4=28
# 7x5=35
# 7x6=42
# 7x7=49
# 7x8=56
# 7x9=63
# 8x1=8
# 8x2=16
# 8x3=24
# 8x4=32
# 8x5=40
# 8x6=48
# 8x7=56
# 8x8=64
# 8x9=72
# 9x1=9
# 9x2=18
# 9x3=27
# 9x4=36
# 9x5=45
# 9x6=54
# 9x7=63
# 9x8=72
# 9x9=81

# %%
for 변수 이터러블:
    반복할 명령어

# %%
a=[1, 3, 5, 7]
for i in a :
    print(i)
# Out:
# 1
# 3
# 5
# 7

# %%
i=1
while i!=5:
    i+=1
    print("Hello")
    i=int(input("숫자(단, 5 입력하면 바로 종료):"))

print("종료")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# 종료

# %%
h=1
for i in range(1,11):
    if i %2==0:
        continue
    print(i, end=" ")
h+=h
# Out:
# 1 3 5 7 9

# %%
import random
a=random.randint(1,100)
x=0
'''print(a)'''

while b!=a:
    b=int(input("숫자(1~100) 입력:"))
    print(b)
    x+=1
    if x>10:
        print("기회 전부 소모")
        break
    else:
        if b>a:
            print("다운")
        elif b<a:
            print("업")
        else :
            print("정답")
            print(f"{x}번 만에 맞춤")

print("종료")
# Out:
# 86
# 86
# 정답
# 1번 만에 맞춤
# 종료

# %%
s=int(input("별 갯수 입력:"))
print("별 갯수:", s)
i=1

while s!=0:
    if s>i:
        print("*"*i)
        s-=i   
        i+=1
        if i>10:
            break
    else :
        print("*"*s)
        break
# Out:
# 별 갯수: 58
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
s=int(input("별 갯수 입력:"))
print("별 갯수:", s)

for i in range(1,11):
    if s>i:
        print('*'*i)
        s-=i
    else:
        print('*'*s)
        break
# Out:
# 별 갯수: 33
# *
# **
# ***
# ****
# *****
# ******
# *******
# *****

# %%
a= "Hello, Python"
a[::-1]
# Out:
# 'nohtyP ,olleH'

# %%
n=[10, "apple", True,[30,50,60]]
a=n[3]
a[1]
# Out:
# 50

# %%
n=[10, "apple", True,[30,50,60]]
n[3][1]
# Out:
# 50

# %%
n=[10, "apple", True,[30,50,60]]
n[1:3]=20, 30
print(n)
# Out:
# [10, 20, 30, [30, 50, 60]]

# %% [markdown]
# ##### 리스트 조작함수

# %%
n=[10,20,66,37,80,98]
n.append(10)
n.remove(10)
n.pop(1)
n.insert(1,38)
n.sort(reverse=True)
print(n)
print(len(n))
min(n)
# Out:
# [98, 80, 38, 37, 20, 10]
# 6
# 10

# %%
n=[10,23,53,74,92]
print(sum(n)/len(n))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[190], line 2
#       1 n=[10,23,53,74,92]
# ----> 2 print(sum(n)/len(n))
#
# TypeError: 'int' object is not callable

# %%
print("끝말잇기 게임")
print("시작")
a="가나다"
print(a)

while True:
    b=str(input("다음 말:"))
    if a[-1]==b[0] :
        print(b)
        a=b
    else :
        break

print("종료")
# Out:
# 끝말잇기 게임
# 시작
# 가나다
# 다람쥐
# 쥐나리
# 리본
# 본드
# 드라이기
# 기록
# 록기
# 기록
# 록기
# 종료

# %%
x=0

while True: 
    if x<20:
        for i in range(20):
            x+=1
            if x%5==0:
                break
            elif x%3==0:
                break
            else:
                print(x, end=" ")
    else:
        break
# Out:
# 1 2 4 7 8 11 13 14 16 17 19
