# %% [markdown]
# ## 함수 복습

# %%
#소수 판별 is_prime()
'''[2,3,4,5,6,7,8,9] -> [True, True, False, True, False, True, False, False]'''
# Out:
# '[2,3,4,5,6,7,8,9] -> [True, True, False, True, False, True, False, False]'

# %%
'''def is_prime(a)
    [2,3,4,5,6,7,8,9]'''
# Out:
# 'def is_prime(a)\n    [2,3,4,5,6,7,8,9]'

# %%
n=int(input())

isprime=True

for i in range(2, n):
    if n%i ==0:
        isprime=False
        break

print(isprime)
# Out:
# True

# %%
def is_prime(num_list):
    result = []
    for num in num_list:
        isprime = True
        for i in range(2, num):
            if num % i == 0:
                isprime = False
                break
        result.append(isprime)
    return result

# %%
import time
 
size = 1_000_000
py_list = list(range(size))
np_array = np.arange(size)
 
start_time = time.time()
result_list = [x * 2 for x in py_list]
end_time = time.time()
print(f'Python 리스트 연산: {end_time - start_time:.5f}초')
 
start_time = time.time()
result_array = np_array * 2
end_time = time.time()
print(f'Numpy 배열 연산: {end_time - start_time:.5f}초')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       3 size = 1_000_000
#       4 py_list = list(range(size))
# ----> 5 np_array = np.arange(size)
#       7 start_time = time.time()
#       8 result_list = [x * 2 for x in py_list]
#
# NameError: name 'np' is not defined
